# %%
from typing import Any

import pandas as pd
import numpy as np

import cirpy
from pandas import Series, DataFrame
from pandas.core.generic import NDFrame

from pubchempy import get_compounds, Compound

# %%
import logging

logging.getLogger('pubchempy').setLevel(logging.DEBUG)

# %%
add_df = pd.read_csv("data/mce_library_add_compounds.csv", sep="\t")
add_df
# Out:
#        RackCode Plate Location mixed_location_plate1 mixed_location_plate2  \
# 0    HYCPK16568             A2               1D3_K20               2D3_K20
# 1    HYCPK16568             A3               1D3_K20               2D3_K20
# 2    HYCPK16568             A4               1D3_K20               2D3_K20
# 3    HYCPK16568             A5               1D3_K20               2D3_K20
# 4    HYCPK16568             A6               1D3_K20               2D3_K20
# ..          ...            ...                   ...                   ...
# 230  HYCPK16573             B3               1D3_L19               2D3_L19
# 231  HYCPK16573             B4               1D3_L19               1D3_L19
# 232  HYCPK16573             B5               1D3_L19               1D3_L19
# 233  HYCPK16573             B6               1D3_L19               1D3_L19
# 234  HYCPK16573             B7               1D3_L19               1D3_L19
#
#     mixed_location_plate3   VialCode   Cat. No.  \
# 0                 3D3_K20        NaN   HY-50880
# 1                 3D3_K20        NaN   HY-15989
# 2                 3D3_K20        NaN  HY-U00094
# 3                 3D3_K20        NaN   HY-12484
# 4                 3D3_K20        NaN   HY-B1434
# ..                    ...        ...        ...
# 230               3D3_L19        NaN  HY-101916
# 231               1D3_L19        NaN  HY-17567C
# 232               1D3_L19        NaN  HY-107910
# 233               1D3_L19        NaN  HY-17567B
# 234               1D3_L19        NaN  HJY-A0276
#
#                            Product Name  Synonyms      CAS No.  ...  \
# 0            Elacridar  (hydrochloride)       NaN  143851-98-3  ...
# 1                                SM-164       NaN  957135-43-2  ...
# 2                               INO5042       NaN   14782-19-5  ...
# 3                                BMH-21       NaN  896705-16-1  ...
# 4             7-Aminophelosporanic acid       NaN     957-68-6  ...
# ..                                  ...       ...          ...  ...
# 230                     Heparan Sulfate       NaN    9050-30-0  ...
# 231  Heparin (sodium salt) (MW 135 kDa)       NaN     9041-8-1  ...
# 232                       Hyaluronidase       NaN   37326-33-3  ...
# 233              Heparin (lithium salt)       NaN    9045-22-1  ...
# 234                Gentamicin (sulfate)       NaN    1405-41-0  ...
#
#      Solubility Solvent Batch No.  Quantity  URL  Pathway  Research Area  \
# 0           NaN     NaN       NaN       NaN  NaN      NaN            NaN
# 1           NaN     NaN       NaN       NaN  NaN      NaN            NaN
# 2           NaN     NaN       NaN       NaN  NaN      NaN            NaN
# 3           NaN     NaN       NaN       NaN  NaN      NaN            NaN
# 4           NaN     NaN       NaN       NaN  NaN      NaN            NaN
# ..          ...     ...       ...       ...  ...      ...            ...
# 230         NaN     NaN       NaN       NaN  NaN      NaN            NaN
# 231         NaN     NaN       NaN       NaN  NaN      NaN            NaN
# 232         NaN     NaN       NaN       NaN  NaN      NaN            NaN
# 233         NaN     NaN       NaN       NaN  NaN      NaN            NaN
# 234         NaN     NaN       NaN       NaN  NaN      NaN            NaN
#
#      Clinical Information  WellNumber  WellLetter
# 0                     NaN           2           A
# 1                     NaN           3           A
# 2                     NaN           4           A
# 3                     NaN           5           A
# 4                     NaN           6           A
# ..                    ...         ...         ...
# 230                   NaN           3           B
# 231                   NaN           4           B
# 232                   NaN           5           B
# 233                   NaN           6           B
# 234                   NaN           7           B
#
# [235 rows x 26 columns]

# %%
def compound_score(comp: Compound):
    smiles = comp.canonical_smiles
    if not smiles:
        return 0
    return 1000 - str(smiles).count(".")


def cas_to_pubchem(cas: str) -> Compound | None:
    if cas == "NaN":
        return None
    compounds = get_compounds(cas, "name")
    if not compounds:
        logging.info("cas:{} had NO entries".format(cas))
        return None
    else:
        compounds.sort(key=lambda comp: compound_score(comp), reverse=True)
        return compounds[0]

# %%
compounds = [cas_to_pubchem(str(cas)) if not pd.isnull(cas) else np.NAN for cas in add_df["CAS No."]]
# Out:
# DEBUG:pubchempy:Request URL: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/JSON
# DEBUG:pubchempy:Request data: b'name=143851-98-3'
# DEBUG:pubchempy:Created Compound(170320)
# DEBUG:pubchempy:Request URL: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/JSON
# DEBUG:pubchempy:Request data: b'name=957135-43-2'
# DEBUG:pubchempy:Created Compound(17756618)
# DEBUG:pubchempy:Created Compound(73409610)
# DEBUG:pubchempy:Created Compound(122172970)
# DEBUG:pubchempy:Created Compound(129626571)
# DEBUG:pubchempy:Created Compound(134692765)
# DEBUG:pubchempy:Created Compound(138107685)
# DEBUG:pubchempy:Request URL: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/JSON
# DEBUG:pubchempy:Request data: b'name=14782-19-5'
# DEBUG:pubchempy:Created Compound(10446437)
# DEBUG:pubchempy:Request URL: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/JSON
# DEBUG:pubchempy:Request data: b'name=896705-16-1'
# DEBUG:pubchempy:Created Compound(3508054)
# DEBUG:pubchempy:Request URL: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/JSON
# DEBUG:pubchempy:Request data: b'name=957-68-6'
# DEBUG:pubchempy:Created Compound(441328)
# DEBUG:pubchempy:Request URL: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/JSON
# DEBUG:pubchempy:Request data: b'name=1241537-79-0'
# DEBUG:pubchempy:Created Compound(46898309)
# DEBUG:pubchempy:Request URL: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/JSON
# DEBUG:pubchempy:Request data: b'name=630-94-4'
# DEBUG:pubchempy:Created Compound(44568160)
# DEBUG:pubchempy:Request URL: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/JSON
# DEBUG:pubchempy:Request data: b'name=10510-54-0'
# DEBUG:pubchempy:Created Compound(82686)
# DEBUG:pubchempy:Created Compound(135445693)
# DEBUG:pubchempy:Created Compound(44134641)
# DEBUG:pubchempy:Request URL: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/JSON
# DEBUG:pubchempy:Request data: b'name=331862-41-0'
# DEBUG:pubchempy:Created Compound(1354721)
# DEBUG:pubchempy:Created Compound(2858716)
# DEBUG:pubchempy:Created Compound(1354723)
# DEBUG:pubchempy:Request URL: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/JSON
# DEBUG:pubchempy:Request data: b'name=154447-35-5'
# DEBUG:pubchempy:Created Compound(9860529)
# DEBUG:pubchempy:Request URL: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/JSON
# DEBUG:pubchempy:Request data: b'name=1029939-86-3'
# DEBUG:pubchempy:Created Compound(24999143)
# DEBUG:pubchempy:Request URL: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/JSON
# DEBUG:pubchempy:Request data: b'name=25322-68-3'
# INFO:pubchempy:'PUGREST.NotFound: No CID found that matches the given name'
# DEBUG:pubchempy:Request URL: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/JSON
# DEBUG:pubchempy:Request data: b'name=2361139-70-8'
# DEBUG:pubchempy:Created Compound(138393291)
# DEBUG:pubchempy:Request URL: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/JSON
# DEBUG:pubchempy:Request data: b'name=1421227-52-2'
# DEBUG:pubchempy:Created Compound(72551586)
# DEBUG:pubchempy:Request URL: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/JSON
# DEBUG:pubchempy:Request data: b'name=25524-16-4'
# INFO:pubchempy:'PUGREST.NotFound: No CID found that matches the given name'
# DEBUG:pubchempy:Request URL: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/JSON
# DEBUG:pubchempy:Request data: b'name=171179-06-9'
# DEBUG:pubchempy:Created Compound(4707)
# DEBUG:pubchempy:Request URL: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/JSON
# DEBUG:pubchempy:Request data: b'name=1427782-89-5'
# DEBUG:pubchempy:Created Compound(71601111)
# DEBUG:pubchempy:Request URL: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/JSON
# DEBUG:pubchempy:Request data: b'name=105956-97-6'
# DEBUG:pubchempy:Created Compound(60063)
# DEBUG:pubchempy:Request URL: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/JSON
# DEBUG:pubchempy:Request data: b'name=1050480-30-2'
# DEBUG:pubchempy:Created Compound(16255105)
# DEBUG:pubchempy:Request URL: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/JSON
# DEBUG:pubchempy:Request data: b'name=143664-11-3'
# DEBUG:pubchempy:Created Compound(119373)
# DEBUG:pubchempy:Request URL: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/JSON
# DEBUG:pubchempy:Request data: b'name=2375555-66-9'
# DEBUG:pubchempy:Created Compound(156599864)
# DEBUG:pubchempy:Request URL: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/JSON
# DEBUG:pubchempy:Request data: b'name=2313230-51-0'
# DEBUG:pubchempy:Created Compound(142572767)
# DEBUG:pubchempy:Request URL: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/JSON
# DEBUG:pubchempy:Request data: b'name=1137868-52-0'
# DEBUG:pubchempy:Created Compound(53357478)
# DEBUG:pubchempy:Request URL: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/JSON
# DEBUG:pubchempy:Request data: b'name=36951-72-1'
# DEBUG:pubchempy:Created Compound(135442972)
# DEBUG:pubchempy:Created Compound(156588360)
# DEBUG:pubchempy:Created Compound(155907175)
# DEBUG:pubchempy:Request URL: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/JSON
# DEBUG:pubchempy:Request data: b'name=545-47-1'
# DEBUG:pubchempy:Created Compound(259846)
# DEBUG:pubchempy:Request URL: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/JSON
# DEBUG:pubchempy:Request data: b'name=374913-63-0'
# DEBUG:pubchempy:Created Compound(135444382)
# DEBUG:pubchempy:Request URL: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/JSON
# DEBUG:pubchempy:Request data: b'name=91809-67-5'
# DEBUG:pubchempy:Created Compound(2762604)
# DEBUG:pubchempy:Request URL: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/JSON
# DEBUG:pubchempy:Request data: b'name=2098546-05-3'
# DEBUG:pubchempy:Created Compound(133081962)
# DEBUG:pubchempy:Request URL: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/JSON
# DEBUG:pubchempy:Request data: b'name=95906-11-9'
# DEBUG:pubchempy:Created Compound(14572930)
# DEBUG:pubchempy:Request URL: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/JSON
# DEBUG:pubchempy:Request data: b'name=1233855-46-3'
# DEBUG:pubchempy:Created Compound(46831476)
# DEBUG:pubchempy:Request URL: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/JSON
# DEBUG:pubchempy:Request data: b'name=784210-88-4'
# DEBUG:pubchempy:Created Compound(11285002)
# DEBUG:pubchempy:Request URL: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/JSON
# DEBUG:pubchempy:Request data: b'name=1002304-34-8'
# DEBUG:pubchempy:Created Compound(24864821)
# DEBUG:pubchempy:Request URL: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/JSON
# DEBUG:pubchempy:Request data: b'name=13860-66-7'
# DEBUG:pubchempy:Created Compound(66970987)
# DEBUG:pubchempy:Request URL: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/JSON
# DEBUG:pubchempy:Request data: b'name=1841460-82-9'
# DEBUG:pubchempy:Created Compound(124203921)
# DEBUG:pubchempy:Request URL: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/JSON
# DEBUG:pubchempy:Request data: b'name=792-74-5'
# DEBUG:pubchempy:Created Compound(13099)
# DEBUG:pubchempy:Request URL: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/JSON
# DEBUG:pubchempy:Request data: b'name=998-07-2'
# DEBUG:pubchempy:Created Compound(9852308)
# DEBUG:pubchempy:Request URL: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/JSON
# DEBUG:pubchempy:Request data: b'name=131410-48-5'
# DEBUG:pubchempy:Created Compound(153921)
# DEBUG:pubchempy:Created Compound(24847884)
# DEBUG:pubchempy:Created Compound(91872893)
# DEBUG:pubchempy:Created Compound(71775015)
# DEBUG:pubchempy:Created Compound(101673418)
# DEBUG:pubchempy:Created Compound(123134693)
# DEBUG:pubchempy:Created Compound(146161114)
# DEBUG:pubchempy:Created Compound(156026237)
# DEBUG:pubchempy:Request URL: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/JSON
# DEBUG:pubchempy:Request data: b'name=14698-29-4'
# DEBUG:pubchempy:Created Compound(4628)
# DEBUG:pubchempy:Request URL: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/JSON
# DEBUG:pubchempy:Request data: b'name=149385-65-9'
# DEBUG:pubchempy:Created Compound(10816380)
# DEBUG:pubchempy:Created Compound(4413247)
# DEBUG:pubchempy:Created Compound(124224347)
# DEBUG:pubchempy:Request URL: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/JSON
# DEBUG:pubchempy:Request data: b'name=156635-05-1'
# DEBUG:pubchempy:Created Compound(501398)
# DEBUG:pubchempy:Request URL: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/JSON
# DEBUG:pubchempy:Request data: b'name=298-93-1'
# DEBUG:pubchempy:Created Compound(64965)
# DEBUG:pubchempy:Request URL: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/JSON
# DEBUG:pubchempy:Request data: b'name=1937-37-7'
# DEBUG:pubchempy:Created Compound(5284349)
# DEBUG:pubchempy:Created Compound(156592250)
# DEBUG:pubchempy:Created Compound(5284350)
# DEBUG:pubchempy:Created Compound(101593232)
# DEBUG:pubchempy:Created Compound(135422071)
# DEBUG:pubchempy:Created Compound(139035018)
# DEBUG:pubchempy:Request URL: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/JSON
# DEBUG:pubchempy:Request data: b'name=34839-70-8'
# DEBUG:pubchempy:Created Compound(1548992)
# DEBUG:pubchempy:Request URL: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/JSON
# DEBUG:pubchempy:Request data: b'name=1449277-10-4'
# DEBUG:pubchempy:Created Compound(89730041)
# DEBUG:pubchempy:Request URL: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/JSON
# DEBUG:pubchempy:Request data: b'name=129791-92-0'
# DEBUG:pubchempy:Created Compound(135431094)
# DEBUG:pubchempy:Created Compound(135867541)
# DEBUG:pubchempy:Created Compound(136199652)
# DEBUG:pubchempy:Created Compound(146156883)
# DEBUG:pubchempy:Created Compound(136493723)
# DEBUG:pubchempy:Created Compound(137265511)
# DEBUG:pubchempy:Request URL: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/JSON
# DEBUG:pubchempy:Request data: b'name=155683-00-4'
# DEBUG:pubchempy:Created Compound(91973814)
# DEBUG:pubchempy:Request URL: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/JSON
# DEBUG:pubchempy:Request data: b'name=2070009-31-1'
# DEBUG:pubchempy:Created Compound(121230976)
# DEBUG:pubchempy:Request URL: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/JSON
# DEBUG:pubchempy:Request data: b'name=19909-90-6'
# INFO:pubchempy:'PUGREST.NotFound: No CID found that matches the given name'
# DEBUG:pubchempy:Request URL: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/JSON
# DEBUG:pubchempy:Request data: b'name=952849-76-2'
# DEBUG:pubchempy:Created Compound(16854524)
# DEBUG:pubchempy:Request URL: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/JSON
# DEBUG:pubchempy:Request data: b'name=862896-30-8'
# DEBUG:pubchempy:Created Compound(11380684)
# DEBUG:pubchempy:Request URL: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/JSON
# DEBUG:pubchempy:Request data: b'name=544-31-0'
# DEBUG:pubchempy:Created Compound(4671)
# DEBUG:pubchempy:Request URL: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/JSON
# DEBUG:pubchempy:Request data: b'name=1800340-40-2'
# DEBUG:pubchempy:Created Compound(118196485)
# DEBUG:pubchempy:Request URL: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/JSON
# DEBUG:pubchempy:Request data: b'name=849675-66-7'
# DEBUG:pubchempy:Created Compound(11399764)
# DEBUG:pubchempy:Request URL: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/JSON
# DEBUG:pubchempy:Request data: b'name=677338-12-4'
# DEBUG:pubchempy:Created Compound(135398491)
# DEBUG:pubchempy:Request URL: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/JSON
# DEBUG:pubchempy:Request data: b'name=1222998-36-8'
# DEBUG:pubchempy:Created Compound(49836027)
# DEBUG:pubchempy:Request URL: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/JSON
# DEBUG:pubchempy:Request data: b'name=87205-99-0'
# DEBUG:pubchempy:Created Compound(11425923)
# DEBUG:pubchempy:Request URL: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/JSON
# DEBUG:pubchempy:Request data: b'name=518-34-3'
# DEBUG:pubchempy:Created Compound(73078)
# DEBUG:pubchempy:Request URL: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/JSON
# DEBUG:pubchempy:Request data: b'name=2361304-26-7'
# DEBUG:pubchempy:Created Compound(138454793)
# DEBUG:pubchempy:Request URL: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/JSON
# DEBUG:pubchempy:Request data: b'name=737763-37-0'
# DEBUG:pubchempy:Created Compound(78357792)
# DEBUG:pubchempy:Request URL: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/JSON
# DEBUG:pubchempy:Request data: b'name=2018282-44-3'
# DEBUG:pubchempy:Created Compound(129012190)
# DEBUG:pubchempy:Request URL: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/JSON
# DEBUG:pubchempy:Request data: b'name=82186-77-4'
# DEBUG:pubchempy:Created Compound(6437380)
# DEBUG:pubchempy:Request URL: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/JSON
# DEBUG:pubchempy:Request data: b'name=2101765-81-3'
# DEBUG:pubchempy:Created Compound(129275747)
# DEBUG:pubchempy:Request URL: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/JSON
# DEBUG:pubchempy:Request data: b'name=2201057-10-3'
# DEBUG:pubchempy:Created Compound(137296045)
# DEBUG:pubchempy:Request URL: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/JSON
# DEBUG:pubchempy:Request data: b'name=187739-60-2'
# DEBUG:pubchempy:Created Compound(11599548)
# DEBUG:pubchempy:Request URL: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/JSON
# DEBUG:pubchempy:Request data: b'name=347323-96-0'
# DEBUG:pubchempy:Created Compound(1362865)
# DEBUG:pubchempy:Created Compound(1362866)
# DEBUG:pubchempy:Created Compound(2880483)
# DEBUG:pubchempy:Request URL: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/JSON
# DEBUG:pubchempy:Request data: b'name=149888-94-8'
# DEBUG:pubchempy:Created Compound(9571003)
# DEBUG:pubchempy:Created Compound(60938)
# DEBUG:pubchempy:Created Compound(6435819)
# DEBUG:pubchempy:Request URL: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/JSON
# DEBUG:pubchempy:Request data: b'name=13063-04-2'
# DEBUG:pubchempy:Created Compound(25659)
# DEBUG:pubchempy:Request URL: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/JSON
# DEBUG:pubchempy:Request data: b'name=112811-59-3'
# DEBUG:pubchempy:Created Compound(5379)
# DEBUG:pubchempy:Request URL: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/JSON
# DEBUG:pubchempy:Request data: b'name=1662-01-7'
# DEBUG:pubchempy:Created Compound(72812)
# DEBUG:pubchempy:Request URL: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/JSON
# DEBUG:pubchempy:Request data: b'name=11061-68-0'
# DEBUG:pubchempy:Created Compound(126843196)
# DEBUG:pubchempy:Created Compound(118984375)
# DEBUG:pubchempy:Created Compound(146674665)
# DEBUG:pubchempy:Request URL: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/JSON
# DEBUG:pubchempy:Request data: b'name=686772-17-8'
# DEBUG:pubchempy:Created Compound(2155264)
# DEBUG:pubchempy:Request URL: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/JSON
# DEBUG:pubchempy:Request data: b'name=682-45-1'
# INFO:pubchempy:'PUGREST.NotFound: No CID found that matches the given name'
# DEBUG:pubchempy:Request URL: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/JSON
# DEBUG:pubchempy:Request data: b'name=13849-08-6'
# DEBUG:pubchempy:Created Compound(334704)
# DEBUG:pubchempy:Request URL: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/JSON
# DEBUG:pubchempy:Request data: b'name=2109805-75-4'
# DEBUG:pubchempy:Created Compound(132585194)
# DEBUG:pubchempy:Request URL: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/JSON
# DEBUG:pubchempy:Request data: b'name=173531-58-3'
# DEBUG:pubchempy:Created Compound(9851774)
# DEBUG:pubchempy:Request URL: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/JSON
# DEBUG:pubchempy:Request data: b'name=5610-40-2'
# DEBUG:pubchempy:Created Compound(442872)
# DEBUG:pubchempy:Request URL: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/JSON
# DEBUG:pubchempy:Request data: b'name=1256589-74-8'
# DEBUG:pubchempy:Created Compound(53239799)
# DEBUG:pubchempy:Request URL: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/JSON
# DEBUG:pubchempy:Request data: b'name=419547-11-8'
# DEBUG:pubchempy:Created Compound(2257249)
# DEBUG:pubchempy:Request URL: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/JSON
# DEBUG:pubchempy:Request data: b'name=8002-43-5'
# DEBUG:pubchempy:Created Compound(5287971)
# DEBUG:pubchempy:Created Compound(122218)
# DEBUG:pubchempy:Created Compound(6438359)
# DEBUG:pubchempy:Created Compound(16213884)
# DEBUG:pubchempy:Created Compound(131706484)
# DEBUG:pubchempy:Request URL: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/JSON
# DEBUG:pubchempy:Request data: b'name=475110-96-4'
# DEBUG:pubchempy:Created Compound(11647372)
# DEBUG:pubchempy:Request URL: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/JSON
# DEBUG:pubchempy:Request data: b'name=2097938-59-3'
# DEBUG:pubchempy:Created Compound(129896913)
# DEBUG:pubchempy:Request URL: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/JSON
# DEBUG:pubchempy:Request data: b'name=882531-87-5'
# DEBUG:pubchempy:Created Compound(135398512)
# DEBUG:pubchempy:Request URL: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/JSON
# DEBUG:pubchempy:Request data: b'name=1579965-12-0'
# DEBUG:pubchempy:Created Compound(73386708)
# DEBUG:pubchempy:Request URL: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/JSON
# DEBUG:pubchempy:Request data: b'name=1437321-24-8'
# DEBUG:pubchempy:Created Compound(71576419)
# DEBUG:pubchempy:Request URL: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/JSON
# DEBUG:pubchempy:Request data: b'name=903564-48-7'
# DEBUG:pubchempy:Created Compound(11714353)
# DEBUG:pubchempy:Request URL: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/JSON
# DEBUG:pubchempy:Request data: b'name=1231929-97-7'
# DEBUG:pubchempy:Created Compound(46220502)
# DEBUG:pubchempy:Request URL: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/JSON
# DEBUG:pubchempy:Request data: b'name=1341200-45-0'
# DEBUG:pubchempy:Created Compound(56839178)
# DEBUG:pubchempy:Request URL: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/JSON
# DEBUG:pubchempy:Request data: b'name=356068-94-5'
# DEBUG:pubchempy:Created Compound(5329106)
# DEBUG:pubchempy:Request URL: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/JSON
# DEBUG:pubchempy:Request data: b'name=2041073-22-5'
# DEBUG:pubchempy:Created Compound(139600315)
# DEBUG:pubchempy:Request URL: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/JSON
# DEBUG:pubchempy:Request data: b'name=1254053-43-4'
# DEBUG:pubchempy:Created Compound(49803313)
# DEBUG:pubchempy:Request URL: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/JSON
# DEBUG:pubchempy:Request data: b'name=1952251-28-3'
# DEBUG:pubchempy:Created Compound(129626432)
# DEBUG:pubchempy:Request URL: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/JSON
# DEBUG:pubchempy:Request data: b'name=942947-93-5'
# DEBUG:pubchempy:Created Compound(16202152)
# DEBUG:pubchempy:Request URL: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/JSON
# DEBUG:pubchempy:Request data: b'name=934541-31-8'
# DEBUG:pubchempy:Created Compound(16124208)
# DEBUG:pubchempy:Request URL: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/JSON
# DEBUG:pubchempy:Request data: b'name=82-08-6'
# DEBUG:pubchempy:Created Compound(5281847)
# DEBUG:pubchempy:Request URL: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/JSON
# DEBUG:pubchempy:Request data: b'name=686770-61-6'
# DEBUG:pubchempy:Created Compound(2155128)
# DEBUG:pubchempy:Request URL: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/JSON
# DEBUG:pubchempy:Request data: b'name=1173204-81-3'
# DEBUG:pubchempy:Created Compound(44187953)
# DEBUG:pubchempy:Request URL: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/JSON
# DEBUG:pubchempy:Request data: b'name=2105956-51-0'
# DEBUG:pubchempy:Created Compound(137628632)
# DEBUG:pubchempy:Request URL: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/JSON
# DEBUG:pubchempy:Request data: b'name=1197953-54-0'
# DEBUG:pubchempy:Created Compound(68165256)
# DEBUG:pubchempy:Request URL: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/JSON
# DEBUG:pubchempy:Request data: b'name=2135642-56-5'
# DEBUG:pubchempy:Created Compound(130447757)
# DEBUG:pubchempy:Request URL: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/JSON
# DEBUG:pubchempy:Request data: b'name=1326852-06-5'
# DEBUG:pubchempy:Created Compound(53333307)
# DEBUG:pubchempy:Request URL: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/JSON
# DEBUG:pubchempy:Request data: b'name=509093-47-4'
# DEBUG:pubchempy:Created Compound(11983295)
# DEBUG:pubchempy:Request URL: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/JSON
# DEBUG:pubchempy:Request data: b'name=867331-82-6'
# DEBUG:pubchempy:Created Compound(11973736)
# DEBUG:pubchempy:Request URL: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/JSON
# DEBUG:pubchempy:Request data: b'name=1254053-84-3'
# DEBUG:pubchempy:Created Compound(76970819)
# DEBUG:pubchempy:Request URL: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/JSON
# DEBUG:pubchempy:Request data: b'name=2138499-06-4'
# DEBUG:pubchempy:Created Compound(139600311)
# DEBUG:pubchempy:Request URL: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/JSON
# DEBUG:pubchempy:Request data: b'name=1392429-79-6'
# DEBUG:pubchempy:Created Compound(60152613)
# DEBUG:pubchempy:Request URL: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/JSON
# DEBUG:pubchempy:Request data: b'name=874819-74-6'
# DEBUG:pubchempy:Created Compound(16034840)
# DEBUG:pubchempy:Request URL: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/JSON
# DEBUG:pubchempy:Request data: b'name=1202055-32-0'
# DEBUG:pubchempy:Created Compound(44556162)
# DEBUG:pubchempy:Request URL: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/JSON
# DEBUG:pubchempy:Request data: b'name=83-46-5'
# DEBUG:pubchempy:Created Compound(222284)
# DEBUG:pubchempy:Request URL: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/JSON
# DEBUG:pubchempy:Request data: b'name=1446790-62-0'
# DEBUG:pubchempy:Created Compound(71626896)
# DEBUG:pubchempy:Request URL: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/JSON
# DEBUG:pubchempy:Request data: b'name=11337883-32-5'
# INFO:pubchempy:'PUGREST.NotFound: No CID found that matches the given name'
# DEBUG:pubchempy:Request URL: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/JSON
# DEBUG:pubchempy:Request data: b'name=226700-81-8'
# DEBUG:pubchempy:Created Compound(131535)
# DEBUG:pubchempy:Request URL: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/JSON
# DEBUG:pubchempy:Request data: b'name=23651-95-8'
# DEBUG:pubchempy:Created Compound(92974)
# DEBUG:pubchempy:Request URL: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/JSON
# DEBUG:pubchempy:Request data: b'name=106344-20-1'
# INFO:pubchempy:'PUGREST.NotFound: No CID found that matches the given name'
# DEBUG:pubchempy:Request URL: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/JSON
# DEBUG:pubchempy:Request data: b'name=2259648-80-9'
# DEBUG:pubchempy:Created Compound(137379043)
# DEBUG:pubchempy:Request URL: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/JSON
# DEBUG:pubchempy:Request data: b'name=2124-57-4'
# DEBUG:pubchempy:Created Compound(5287554)
# DEBUG:pubchempy:Request URL: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/JSON
# DEBUG:pubchempy:Request data: b'name=110117-83-4'
# DEBUG:pubchempy:Created Compound(405012)
# DEBUG:pubchempy:Request URL: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/JSON
# DEBUG:pubchempy:Request data: b'name=175519-16-1'
# DEBUG:pubchempy:Created Compound(10343042)
# DEBUG:pubchempy:Created Compound(70199096)
# DEBUG:pubchempy:Created Compound(45260563)
# DEBUG:pubchempy:Created Compound(45266080)
# DEBUG:pubchempy:Request URL: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/JSON
# DEBUG:pubchempy:Request data: b'name=106017-08-7'
# DEBUG:pubchempy:Created Compound(176015)
# DEBUG:pubchempy:Request URL: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/JSON
# DEBUG:pubchempy:Request data: b'name=290297-26-6'
# DEBUG:pubchempy:Created Compound(6451149)
# DEBUG:pubchempy:Request URL: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/JSON
# DEBUG:pubchempy:Request data: b'name=1138549-36-6'
# DEBUG:pubchempy:Created Compound(25257557)
# DEBUG:pubchempy:Request URL: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/JSON
# DEBUG:pubchempy:Request data: b'name=778576-62-8'
# DEBUG:pubchempy:Created Compound(11387409)
# DEBUG:pubchempy:Request URL: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/JSON
# DEBUG:pubchempy:Request data: b'name=377727-87-2'
# DEBUG:pubchempy:Created Compound(10117987)
# DEBUG:pubchempy:Request URL: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/JSON
# DEBUG:pubchempy:Request data: b'name=1449598-06-4'
# DEBUG:pubchempy:Created Compound(89741565)
# DEBUG:pubchempy:Request URL: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/JSON
# DEBUG:pubchempy:Request data: b'name=78186-34-2'
# DEBUG:pubchempy:Created Compound(5351322)
# DEBUG:pubchempy:Created Compound(5477614)
# DEBUG:pubchempy:Created Compound(51323)
# DEBUG:pubchempy:Request URL: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/JSON
# DEBUG:pubchempy:Request data: b'name=1359993-59-1'
# DEBUG:pubchempy:Created Compound(56833311)
# DEBUG:pubchempy:Request URL: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/JSON
# DEBUG:pubchempy:Request data: b'name=20347-71-1'
# DEBUG:pubchempy:Created Compound(107876)
# DEBUG:pubchempy:Request URL: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/JSON
# DEBUG:pubchempy:Request data: b'name=161605-73-8'
# DEBUG:pubchempy:Created Compound(208953)
# DEBUG:pubchempy:Request URL: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/JSON
# DEBUG:pubchempy:Request data: b'name=1093403-338'
# INFO:pubchempy:'PUGREST.NotFound: No CID found that matches the given name'
# DEBUG:pubchempy:Request URL: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/JSON
# DEBUG:pubchempy:Request data: b'name=79-61-8'
# DEBUG:pubchempy:Created Compound(5388959)
# DEBUG:pubchempy:Request URL: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/JSON
# DEBUG:pubchempy:Request data: b'name=146255-66-5'
# DEBUG:pubchempy:Created Compound(108001)
# DEBUG:pubchempy:Request URL: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/JSON
# DEBUG:pubchempy:Request data: b'name=620112-78-9'
# DEBUG:pubchempy:Created Compound(6057678)
# DEBUG:pubchempy:Request URL: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/JSON
# DEBUG:pubchempy:Request data: b'name=2173037-97-1'
# DEBUG:pubchempy:Created Compound(60096231)
# DEBUG:pubchempy:Request URL: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/JSON
# DEBUG:pubchempy:Request data: b'name=620113-73-7'
# DEBUG:pubchempy:Created Compound(5948316)
# DEBUG:pubchempy:Request URL: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/JSON
# DEBUG:pubchempy:Request data: b'name=40796-97-2'
# DEBUG:pubchempy:Created Compound(671690)
# DEBUG:pubchempy:Request URL: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/JSON
# DEBUG:pubchempy:Request data: b'name=906805-42-3'
# DEBUG:pubchempy:Created Compound(11995774)
# DEBUG:pubchempy:Request URL: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/JSON
# DEBUG:pubchempy:Request data: b'name=303-97-9'
# DEBUG:pubchempy:Created Compound(5280473)
# DEBUG:pubchempy:Request URL: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/JSON
# DEBUG:pubchempy:Request data: b'name=473-98-3'
# DEBUG:pubchempy:Created Compound(72326)
# DEBUG:pubchempy:Request URL: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/JSON
# DEBUG:pubchempy:Request data: b'name=80-97-7'
# DEBUG:pubchempy:Created Compound(6665)
# DEBUG:pubchempy:Request URL: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/JSON
# DEBUG:pubchempy:Request data: b'name=24697-74-3'
# DEBUG:pubchempy:Created Compound(161464)
# DEBUG:pubchempy:Request URL: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/JSON
# DEBUG:pubchempy:Request data: b'name=121123-17-9'
# DEBUG:pubchempy:Created Compound(6436628)
# DEBUG:pubchempy:Created Compound(71307510)
# DEBUG:pubchempy:Created Compound(53394855)
# DEBUG:pubchempy:Created Compound(92088)
# DEBUG:pubchempy:Created Compound(124080948)
# DEBUG:pubchempy:Created Compound(134694148)
# DEBUG:pubchempy:Request URL: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/JSON
# DEBUG:pubchempy:Request data: b'name=206873-63-4'
# DEBUG:pubchempy:Created Compound(148201)
# DEBUG:pubchempy:Request URL: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/JSON
# DEBUG:pubchempy:Request data: b'name=481-74-3'
# DEBUG:pubchempy:Created Compound(10208)
# DEBUG:pubchempy:Request URL: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/JSON
# DEBUG:pubchempy:Request data: b'name=586-38-9'
# DEBUG:pubchempy:Created Compound(11461)
# DEBUG:pubchempy:Request URL: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/JSON
# DEBUG:pubchempy:Request data: b'name=171746-21-7'
# DEBUG:pubchempy:Created Compound(177238)
# DEBUG:pubchempy:Request URL: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/JSON
# DEBUG:pubchempy:Request data: b'name=2140-77-4'
# DEBUG:pubchempy:Created Compound(135501934)
# DEBUG:pubchempy:Request URL: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/JSON
# DEBUG:pubchempy:Request data: b'name=192203-60-4'
# DEBUG:pubchempy:Created Compound(9796834)
# DEBUG:pubchempy:Request URL: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/JSON
# DEBUG:pubchempy:Request data: b'name=81938-43-4'
# DEBUG:pubchempy:Created Compound(3033690)
# DEBUG:pubchempy:Created Compound(14103059)
# DEBUG:pubchempy:Created Compound(9912532)
# DEBUG:pubchempy:Created Compound(123134537)
# DEBUG:pubchempy:Created Compound(54797)
# DEBUG:pubchempy:Request URL: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/JSON
# DEBUG:pubchempy:Request data: b'name=1134-47-0'
# DEBUG:pubchempy:Created Compound(2284)
# DEBUG:pubchempy:Request URL: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/JSON
# DEBUG:pubchempy:Request data: b'name=1516896-09-5'
# DEBUG:pubchempy:Created Compound(72709059)
# DEBUG:pubchempy:Request URL: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/JSON
# DEBUG:pubchempy:Request data: b'name=90-15-3'
# DEBUG:pubchempy:Created Compound(7005)
# DEBUG:pubchempy:Request URL: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/JSON
# DEBUG:pubchempy:Request data: b'name=568-73-0'
# DEBUG:pubchempy:Created Compound(114917)
# DEBUG:pubchempy:Request URL: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/JSON
# DEBUG:pubchempy:Request data: b'name=6537-80-0'
# DEBUG:pubchempy:Created Compound(5281764)
# DEBUG:pubchempy:Request URL: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/JSON
# DEBUG:pubchempy:Request data: b'name=77-59-8'
# DEBUG:pubchempy:Created Compound(65576)
# DEBUG:pubchempy:Request URL: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/JSON
# DEBUG:pubchempy:Request data: b'name=16037-91-5'
# INFO:pubchempy:'PUGREST.NotFound: No CID found that matches the given name'
# DEBUG:pubchempy:Request URL: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/JSON
# DEBUG:pubchempy:Request data: b'name=1456551-16-8'
# DEBUG:pubchempy:Created Compound(72547053)
# DEBUG:pubchempy:Request URL: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/JSON
# DEBUG:pubchempy:Request data: b'name=126-17-0'
# DEBUG:pubchempy:Created Compound(442985)
# DEBUG:pubchempy:Created Compound(5250)
# DEBUG:pubchempy:Created Compound(129316900)
# DEBUG:pubchempy:Created Compound(16061352)
# DEBUG:pubchempy:Created Compound(122172924)
# DEBUG:pubchempy:Created Compound(5200420)
# DEBUG:pubchempy:Created Compound(126961506)
# DEBUG:pubchempy:Created Compound(126961509)
# DEBUG:pubchempy:Request URL: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/JSON
# DEBUG:pubchempy:Request data: b'name=84625-61-6'
# DEBUG:pubchempy:Created Compound(3793)
# DEBUG:pubchempy:Created Compound(55283)
# DEBUG:pubchempy:Created Compound(6917738)
# DEBUG:pubchempy:Created Compound(14179013)
# DEBUG:pubchempy:Created Compound(14179008)
# DEBUG:pubchempy:Created Compound(45039617)
# DEBUG:pubchempy:Request URL: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/JSON
# DEBUG:pubchempy:Request data: b'name=99011-02-6'
# DEBUG:pubchempy:Created Compound(57469)
# DEBUG:pubchempy:Request URL: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/JSON
# DEBUG:pubchempy:Request data: b'name=147127-20-6'
# DEBUG:pubchempy:Created Compound(464205)
# DEBUG:pubchempy:Request URL: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/JSON
# DEBUG:pubchempy:Request data: b'name=85721-33-1'
# DEBUG:pubchempy:Created Compound(2764)
# DEBUG:pubchempy:Request URL: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/JSON
# DEBUG:pubchempy:Request data: b'name=84294-96-2'
# DEBUG:pubchempy:Created Compound(24840537)
# DEBUG:pubchempy:Request URL: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/JSON
# DEBUG:pubchempy:Request data: b'name=155141-29-0'
# DEBUG:pubchempy:Created Compound(5281055)
# DEBUG:pubchempy:Request URL: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/JSON
# DEBUG:pubchempy:Request data: b'name=93106-59-3'
# DEBUG:pubchempy:Created Compound(45357113)
# DEBUG:pubchempy:Request URL: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/JSON
# DEBUG:pubchempy:Request data: b'name=879-37-8'
# DEBUG:pubchempy:Created Compound(397)
# DEBUG:pubchempy:Request URL: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/JSON
# DEBUG:pubchempy:Request data: b'name=94424-50-7'
# DEBUG:pubchempy:Created Compound(3086400)
# DEBUG:pubchempy:Request URL: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/JSON
# DEBUG:pubchempy:Request data: b'name=7432-28-2'
# DEBUG:pubchempy:Created Compound(23915)
# DEBUG:pubchempy:Created Compound(3001664)
# DEBUG:pubchempy:Created Compound(11102092)
# DEBUG:pubchempy:Created Compound(468078)
# DEBUG:pubchempy:Created Compound(10455507)
# DEBUG:pubchempy:Created Compound(38988908)
# DEBUG:pubchempy:Request URL: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/JSON
# DEBUG:pubchempy:Request data: b'name=2363-71-5'
# DEBUG:pubchempy:Created Compound(16898)
# DEBUG:pubchempy:Request URL: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/JSON
# DEBUG:pubchempy:Request data: b'name=129-74-8'
# DEBUG:pubchempy:Created Compound(65463)
# DEBUG:pubchempy:Request URL: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/JSON
# DEBUG:pubchempy:Request data: b'name=92-61-5'
# DEBUG:pubchempy:Created Compound(5280460)
# DEBUG:pubchempy:Request URL: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/JSON
# DEBUG:pubchempy:Request data: b'name=84104-71-2'
# DEBUG:pubchempy:Created Compound(158477)
# DEBUG:pubchempy:Request URL: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/JSON
# DEBUG:pubchempy:Request data: b'name=469-59-0'
# DEBUG:pubchempy:Created Compound(10098)
# DEBUG:pubchempy:Request URL: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/JSON
# DEBUG:pubchempy:Request data: b'name=123940-54-5'
# DEBUG:pubchempy:Created Compound(1023768)
# DEBUG:pubchempy:Request URL: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/JSON
# DEBUG:pubchempy:Request data: b'name=76958-99-1'
# DEBUG:pubchempy:Created Compound(23685777)
# DEBUG:pubchempy:Created Compound(131884939)
# DEBUG:pubchempy:Request URL: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/JSON
# DEBUG:pubchempy:Request data: b'name=112-85-6'
# DEBUG:pubchempy:Created Compound(8215)
# DEBUG:pubchempy:Request URL: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/JSON
# DEBUG:pubchempy:Request data: b'name=915967-82-7'
# DEBUG:pubchempy:Created Compound(49849842)
# DEBUG:pubchempy:Request URL: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/JSON
# DEBUG:pubchempy:Request data: b'name=6469-93-8'
# DEBUG:pubchempy:Created Compound(5282478)
# DEBUG:pubchempy:Created Compound(71314839)
# DEBUG:pubchempy:Request URL: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/JSON
# DEBUG:pubchempy:Request data: b'name=474-58-8'
# DEBUG:pubchempy:Created Compound(5742590)
# DEBUG:pubchempy:Request URL: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/JSON
# DEBUG:pubchempy:Request data: b'name=83-46-5'
# DEBUG:pubchempy:Created Compound(222284)
# DEBUG:pubchempy:Request URL: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/JSON
# DEBUG:pubchempy:Request data: b'name=110871-86-8'
# DEBUG:pubchempy:Created Compound(60464)
# DEBUG:pubchempy:Request URL: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/JSON
# DEBUG:pubchempy:Request data: b'name=1405-87-4'
# INFO:pubchempy:'PUGREST.NotFound: No CID found that matches the given name'
# DEBUG:pubchempy:Request URL: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/JSON
# DEBUG:pubchempy:Request data: b'name=2108830-08-4'
# DEBUG:pubchempy:Created Compound(91826512)
# DEBUG:pubchempy:Request URL: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/JSON
# DEBUG:pubchempy:Request data: b'name=151533-22-1'
# DEBUG:pubchempy:Created Compound(135564391)
# DEBUG:pubchempy:Created Compound(135743635)
# DEBUG:pubchempy:Created Compound(136219116)
# DEBUG:pubchempy:Created Compound(135854451)
# DEBUG:pubchempy:Created Compound(102132842)
# DEBUG:pubchempy:Created Compound(138107192)
# DEBUG:pubchempy:Request URL: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/JSON
# DEBUG:pubchempy:Request data: b'name=165800-06-6'
# DEBUG:pubchempy:Created Compound(121586)
# DEBUG:pubchempy:Request URL: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/JSON
# DEBUG:pubchempy:Request data: b'name=106941-25-7'
# DEBUG:pubchempy:Created Compound(60172)
# DEBUG:pubchempy:Request URL: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/JSON
# DEBUG:pubchempy:Request data: b'name=1758-80-1'
# DEBUG:pubchempy:Created Compound(134490)
# DEBUG:pubchempy:Created Compound(46735201)
# DEBUG:pubchempy:Created Compound(6971272)
# DEBUG:pubchempy:Created Compound(138398292)
# DEBUG:pubchempy:Request URL: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/JSON
# DEBUG:pubchempy:Request data: b'name=526-31-8'
# DEBUG:pubchempy:Created Compound(160511)
# DEBUG:pubchempy:Request URL: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/JSON
# DEBUG:pubchempy:Request data: b'name=69-93-2'
# DEBUG:pubchempy:Created Compound(1175)
# DEBUG:pubchempy:Request URL: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/JSON
# DEBUG:pubchempy:Request data: b'name=56-88-2'
# DEBUG:pubchempy:Created Compound(439258)
# DEBUG:pubchempy:Request URL: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/JSON
# DEBUG:pubchempy:Request data: b'name=9008-22-4'
# DEBUG:pubchempy:Created Compound(439306)
# DEBUG:pubchempy:Created Compound(154805957)
# DEBUG:pubchempy:Request URL: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/JSON
# DEBUG:pubchempy:Request data: b'name=61909-81-7'
# DEBUG:pubchempy:Created Compound(124898)
# DEBUG:pubchempy:Created Compound(137699175)
# DEBUG:pubchempy:Request URL: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/JSON
# DEBUG:pubchempy:Request data: b'name=128446-35-5'
# DEBUG:pubchempy:Created Compound(56972821)
# DEBUG:pubchempy:Created Compound(4363642)
# DEBUG:pubchempy:Created Compound(90479739)
# DEBUG:pubchempy:Request URL: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/JSON
# DEBUG:pubchempy:Request data: b'name=9036-06-0'
# INFO:pubchempy:'PUGREST.NotFound: No CID found that matches the given name'
# DEBUG:pubchempy:Request URL: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/JSON
# DEBUG:pubchempy:Request data: b'name=8024-48-4'
# DEBUG:pubchempy:Created Compound(2098)
# DEBUG:pubchempy:Request URL: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/JSON
# DEBUG:pubchempy:Request data: b'name=9004-65-3'
# INFO:pubchempy:'PUGREST.NotFound: No CID found that matches the given name'
# DEBUG:pubchempy:Request URL: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/JSON
# DEBUG:pubchempy:Request data: b'name=8047-15-2'
# DEBUG:pubchempy:Created Compound(198016)
# DEBUG:pubchempy:Created Compound(22715020)
# DEBUG:pubchempy:Created Compound(163408272)
# DEBUG:pubchempy:Request URL: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/JSON
# DEBUG:pubchempy:Request data: b'name=9005-53-2'
# INFO:pubchempy:'PUGREST.NotFound: No CID found that matches the given name'
# DEBUG:pubchempy:Request URL: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/JSON
# DEBUG:pubchempy:Request data: b'name=11029-12-2'
# DEBUG:pubchempy:Created Compound(145858)
# DEBUG:pubchempy:Request URL: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/JSON
# DEBUG:pubchempy:Request data: b'name=225937-10-0'
# DEBUG:pubchempy:Created Compound(107957)
# DEBUG:pubchempy:Created Compound(9064)
# DEBUG:pubchempy:Request URL: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/JSON
# DEBUG:pubchempy:Request data: b'name=34346-01-5'
# DEBUG:pubchempy:Created Compound(36797)
# DEBUG:pubchempy:Request URL: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/JSON
# DEBUG:pubchempy:Request data: b'name=60842-46-8'
# INFO:pubchempy:'PUGREST.NotFound: No CID found that matches the given name'
# DEBUG:pubchempy:Request URL: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/JSON
# DEBUG:pubchempy:Request data: b'name=11089-65-9'
# INFO:pubchempy:'PUGREST.NotFound: No CID found that matches the given name'
# DEBUG:pubchempy:Request URL: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/JSON
# DEBUG:pubchempy:Request data: b'name=1405-20-5'
# DEBUG:pubchempy:Created Compound(5702105)
# DEBUG:pubchempy:Created Compound(49800003)
# DEBUG:pubchempy:Created Compound(133109994)
# DEBUG:pubchempy:Created Compound(138106890)
# DEBUG:pubchempy:Request URL: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/JSON
# DEBUG:pubchempy:Request data: b'name=149003-01-0'
# DEBUG:pubchempy:Created Compound(6918223)
# DEBUG:pubchempy:Request URL: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/JSON
# DEBUG:pubchempy:Request data: b'name=25301-02-4'
# DEBUG:pubchempy:Created Compound(71388)
# DEBUG:pubchempy:Request URL: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/JSON
# DEBUG:pubchempy:Request data: b'name=9001-92-7'
# INFO:pubchempy:'PUGREST.NotFound: No CID found that matches the given name'
# DEBUG:pubchempy:Request URL: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/JSON
# DEBUG:pubchempy:Request data: b'name=9003-3-8'
# INFO:pubchempy:'PUGREST.NotFound: No CID found that matches the given name'
# DEBUG:pubchempy:Request URL: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/JSON
# DEBUG:pubchempy:Request data: b'name=345909-26-4'
# DEBUG:pubchempy:Created Compound(23687511)
# DEBUG:pubchempy:Created Compound(23696721)
# DEBUG:pubchempy:Created Compound(138114966)
# DEBUG:pubchempy:Created Compound(163199392)
# DEBUG:pubchempy:Request URL: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/JSON
# DEBUG:pubchempy:Request data: b'name=25655-41-8'
# DEBUG:pubchempy:Created Compound(410087)
# DEBUG:pubchempy:Request URL: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/JSON
# DEBUG:pubchempy:Request data: b'name=1504602-49-6'
# DEBUG:pubchempy:Created Compound(11993702)
# DEBUG:pubchempy:Request URL: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/JSON
# DEBUG:pubchempy:Request data: b'name=1401-20-3'
# INFO:pubchempy:'PUGREST.NotFound: No CID found that matches the given name'
# DEBUG:pubchempy:Request URL: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/JSON
# DEBUG:pubchempy:Request data: b'name=26027-38-3'
# DEBUG:pubchempy:Created Compound(7700)
# DEBUG:pubchempy:Request URL: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/JSON
# DEBUG:pubchempy:Request data: b'name=182410-00-0'
# INFO:pubchempy:'PUGREST.NotFound: No CID found that matches the given name'
# DEBUG:pubchempy:Request URL: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/JSON
# DEBUG:pubchempy:Request data: b'name=9014-63-5'
# INFO:pubchempy:'PUGREST.NotFound: No CID found that matches the given name'
# DEBUG:pubchempy:Request URL: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/JSON
# DEBUG:pubchempy:Request data: b'name=9005-80-5'
# INFO:pubchempy:'PUGREST.NotFound: No CID found that matches the given name'
# DEBUG:pubchempy:Request URL: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/JSON
# DEBUG:pubchempy:Request data: b'name=76494-51-4'
# DEBUG:pubchempy:Created Compound(156709)
# DEBUG:pubchempy:Request URL: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/JSON
# DEBUG:pubchempy:Request data: b'name=1309573-60-1'
# DEBUG:pubchempy:Created Compound(149533007)
# DEBUG:pubchempy:Created Compound(154805956)
# DEBUG:pubchempy:Request URL: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/JSON
# DEBUG:pubchempy:Request data: b'name=9007-28-7'
# DEBUG:pubchempy:Created Compound(24766)
# DEBUG:pubchempy:Request URL: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/JSON
# DEBUG:pubchempy:Request data: b'name=123408-98-0'
# DEBUG:pubchempy:Created Compound(56845531)
# DEBUG:pubchempy:Request URL: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/JSON
# DEBUG:pubchempy:Request data: b'name=352195-40-5'
# DEBUG:pubchempy:Created Compound(135565601)
# DEBUG:pubchempy:Request URL: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/JSON
# DEBUG:pubchempy:Request data: b'name=8049-47-6'
# INFO:pubchempy:'PUGREST.NotFound: No CID found that matches the given name'
# DEBUG:pubchempy:Request URL: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/JSON
# DEBUG:pubchempy:Request data: b'name=9008-97-3'
# INFO:pubchempy:'PUGREST.NotFound: No CID found that matches the given name'
# DEBUG:pubchempy:Request URL: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/JSON
# DEBUG:pubchempy:Request data: b'name=28728-55-4'
# DEBUG:pubchempy:Created Compound(24769)
# DEBUG:pubchempy:Request URL: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/JSON
# DEBUG:pubchempy:Request data: b'name=14811-57-8'
# INFO:pubchempy:'PUGREST.NotFound: No CID found that matches the given name'
# DEBUG:pubchempy:Request URL: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/JSON
# DEBUG:pubchempy:Request data: b'name=207300-85-4'
# DEBUG:pubchempy:Created Compound(155289790)
# DEBUG:pubchempy:Request URL: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/JSON
# DEBUG:pubchempy:Request data: b'name=9002-92-0'
# INFO:pubchempy:'PUGREST.NotFound: No CID found that matches the given name'
# DEBUG:pubchempy:Request URL: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/JSON
# DEBUG:pubchempy:Request data: b'name=91080-16-9'
# INFO:pubchempy:'PUGREST.NotFound: No CID found that matches the given name'
# DEBUG:pubchempy:Request URL: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/JSON
# DEBUG:pubchempy:Request data: b'name=1326-12-1'
# DEBUG:pubchempy:Created Compound(16953)
# DEBUG:pubchempy:Request URL: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/JSON
# DEBUG:pubchempy:Request data: b'name=9050-30-0'
# DEBUG:pubchempy:Created Compound(137699201)
# DEBUG:pubchempy:Request URL: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/JSON
# DEBUG:pubchempy:Request data: b'name=9041-8-1'
# INFO:pubchempy:'PUGREST.NotFound: No CID found that matches the given name'
# DEBUG:pubchempy:Request URL: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/JSON
# DEBUG:pubchempy:Request data: b'name=37326-33-3'
# DEBUG:pubchempy:Created Compound(91820602)
# DEBUG:pubchempy:Request URL: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/JSON
# DEBUG:pubchempy:Request data: b'name=9045-22-1'
# DEBUG:pubchempy:Created Compound(44336410)
# DEBUG:pubchempy:Request URL: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/JSON
# DEBUG:pubchempy:Request data: b'name=1405-41-0'
# INFO:pubchempy:'PUGREST.NotFound: No CID found that matches the given name'

# %%
add_df["PubChemID"] = pd.array([compound.cid if not pd.isnull(compound) else np.NAN for compound in compounds], dtype=pd.Int64Dtype())
add_df["isomeric_smiles"] = [compound.isomeric_smiles if not pd.isnull(compound) else np.NAN for compound in compounds]
add_df["canonical_smiles"] = [compound.canonical_smiles if not pd.isnull(compound) else np.NAN for compound in compounds]
add_df
# Out:
#        RackCode Plate Location mixed_location_plate1 mixed_location_plate2  \
# 0    HYCPK16568             A2               1D3_K20               2D3_K20
# 1    HYCPK16568             A3               1D3_K20               2D3_K20
# 2    HYCPK16568             A4               1D3_K20               2D3_K20
# 3    HYCPK16568             A5               1D3_K20               2D3_K20
# 4    HYCPK16568             A6               1D3_K20               2D3_K20
# ..          ...            ...                   ...                   ...
# 230  HYCPK16573             B3               1D3_L19               2D3_L19
# 231  HYCPK16573             B4               1D3_L19               1D3_L19
# 232  HYCPK16573             B5               1D3_L19               1D3_L19
# 233  HYCPK16573             B6               1D3_L19               1D3_L19
# 234  HYCPK16573             B7               1D3_L19               1D3_L19
#
#     mixed_location_plate3   VialCode   Cat. No.  \
# 0                 3D3_K20        NaN   HY-50880
# 1                 3D3_K20        NaN   HY-15989
# 2                 3D3_K20        NaN  HY-U00094
# 3                 3D3_K20        NaN   HY-12484
# 4                 3D3_K20        NaN   HY-B1434
# ..                    ...        ...        ...
# 230               3D3_L19        NaN  HY-101916
# 231               1D3_L19        NaN  HY-17567C
# 232               1D3_L19        NaN  HY-107910
# 233               1D3_L19        NaN  HY-17567B
# 234               1D3_L19        NaN  HJY-A0276
#
#                            Product Name  Synonyms      CAS No.  ...  Quantity  \
# 0            Elacridar  (hydrochloride)       NaN  143851-98-3  ...       NaN
# 1                                SM-164       NaN  957135-43-2  ...       NaN
# 2                               INO5042       NaN   14782-19-5  ...       NaN
# 3                                BMH-21       NaN  896705-16-1  ...       NaN
# 4             7-Aminophelosporanic acid       NaN     957-68-6  ...       NaN
# ..                                  ...       ...          ...  ...       ...
# 230                     Heparan Sulfate       NaN    9050-30-0  ...       NaN
# 231  Heparin (sodium salt) (MW 135 kDa)       NaN     9041-8-1  ...       NaN
# 232                       Hyaluronidase       NaN   37326-33-3  ...       NaN
# 233              Heparin (lithium salt)       NaN    9045-22-1  ...       NaN
# 234                Gentamicin (sulfate)       NaN    1405-41-0  ...       NaN
#
#     URL Pathway  Research Area  Clinical Information  WellNumber  WellLetter  \
# 0   NaN     NaN            NaN                   NaN           2           A
# 1   NaN     NaN            NaN                   NaN           3           A
# 2   NaN     NaN            NaN                   NaN           4           A
# 3   NaN     NaN            NaN                   NaN           5           A
# 4   NaN     NaN            NaN                   NaN           6           A
# ..   ..     ...            ...                   ...         ...         ...
# 230 NaN     NaN            NaN                   NaN           3           B
# 231 NaN     NaN            NaN                   NaN           4           B
# 232 NaN     NaN            NaN                   NaN           5           B
# 233 NaN     NaN            NaN                   NaN           6           B
# 234 NaN     NaN            NaN                   NaN           7           B
#
#      PubChemID                                    isomeric_smiles  \
# 0       170320  COC1=CC=CC2=C1NC3=C(C2=O)C=CC=C3C(=O)NC4=CC=C(...
# 1     17756618  C[C@@H](C(=O)N[C@H]1CCCC[C@H]2CC[C@H](N2C1=O)C...
# 2     10446437      C1=CC=C2C(=C1)C(=O)C3=C(C2=O)SC(=N3)C4=CC=CO4
# 3      3508054  CN(C)CCNC(=O)C1=CC=CN2C1=NC3=CC4=CC=CC=C4C=C3C2=O
# 4       441328     CC(=O)OCC1=C(N2[C@@H]([C@@H](C2=O)N)SC1)C(=O)O
# ..         ...                                                ...
# 230  137699201  CO[C@@H]1[C@@H]([C@@H]([C@@H](OC1C(=O)[O-])O[C...
# 231       <NA>                                                NaN
# 232   91820602           CC1(C(=C)N(C2=CC=CC=C21)CCCCCC(=O)O)C.Br
# 233   44336410  COC1C(C(C(OC1C(=O)O)OC2C(OC(C(C2O)NS(=O)(=O)O)...
# 234       <NA>                                                NaN
#
#                                       canonical_smiles
# 0    COC1=CC=CC2=C1NC3=C(C2=O)C=CC=C3C(=O)NC4=CC=C(...
# 1    CC(C(=O)NC1CCCCC2CCC(N2C1=O)C(=O)NC(C3=CC=CC=C...
# 2        C1=CC=C2C(=C1)C(=O)C3=C(C2=O)SC(=N3)C4=CC=CO4
# 3    CN(C)CCNC(=O)C1=CC=CN2C1=NC3=CC4=CC=CC=C4C=C3C2=O
# 4                 CC(=O)OCC1=C(N2C(C(C2=O)N)SC1)C(=O)O
# ..                                                 ...
# 230  COC1C(C(C(OC1C(=O)[O-])OC2C(OC(C(C2O)NS(=O)(=O...
# 231                                                NaN
# 232           CC1(C(=C)N(C2=CC=CC=C21)CCCCCC(=O)O)C.Br
# 233  COC1C(C(C(OC1C(=O)O)OC2C(OC(C(C2O)NS(=O)(=O)O)...
# 234                                                NaN
#
# [235 rows x 29 columns]

# %%
comp = cas_to_pubchem('143851-98-3')
float(comp.monoisotopic_mass)
# Out:
# 599.2186989

# %%
cas_to_pubchem("1401-20-3")
# Out:
# DEBUG:pubchempy:Request URL: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/JSON
# DEBUG:pubchempy:Request data: b'name=1401-20-3'
# INFO:pubchempy:'PUGREST.NotFound: No CID found that matches the given name'

# %%
# Out:
# False
