# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import json

# %%
def get_intensities(df, min_ms_level, max_ms_level=None):
    if max_ms_level is None or max_ms_level<=min_ms_level:
        filtered = df[df["MS_LEVEL"]==min_ms_level]
    else:
        filtered = df[df["MS_LEVEL"].between(min_ms_level,max_ms_level, 'both')]
    return np.concatenate(filtered.INTENSITIES.values)

def get_mzs(df: pd.DataFrame, min_ms_level: int, max_ms_level=None):
    if max_ms_level is None or max_ms_level<=min_ms_level:
        filtered = df[df["MS_LEVEL"]==min_ms_level]
    else:
        filtered = df[df["MS_LEVEL"].between(min_ms_level,max_ms_level, 'both')]
    return np.concatenate(filtered.MZS.values)

def get_datapoints(df, min_ms_level, max_ms_level=None):
    if max_ms_level is None or max_ms_level<=min_ms_level:
        filtered = df[df["MS_LEVEL"]==min_ms_level]
    else:
        filtered = df[df["MS_LEVEL"].between(min_ms_level,max_ms_level, 'both')]

    return np.concatenate(filtered.MZS.values), np.concatenate(filtered.INTENSITIES.values)

# %%
def save_fig(file_name):
    plt.savefig("figures/{}.png".format(file_name), dpi=300)
    plt.savefig("figures/{}.pdf".format(file_name))
    plt.savefig("figures/{}.svg".format(file_name))

sns.set_theme(font_scale=2, style="white")

# %%
method1_df = pd.read_csv("data/spectra_match_1D1A_mce_40AGC.csv", sep="\t")
method2_df= pd.read_csv("data/spectra_match_1D1A_mce_100AGC.csv", sep="\t")
method3_df= pd.read_csv("data/spectra_match_1D1A_mce_100AGC_60000.csv", sep="\t")

# %%
method1_df["METHOD"] = "40AGC"
method2_df["METHOD"] = "100AGC"
method3_df["METHOD"] = "100AGC60000Res"

merged_df = pd.concat([method1_df, method2_df, method3_df], ignore_index=True)

merged_df.INTENSITIES = merged_df.INTENSITIES.apply(lambda v: json.loads(v))
merged_df.MZS = merged_df.MZS.apply(lambda v: json.loads(v))
merged_df.PRECURSOR_LIST = merged_df.PRECURSOR_LIST.apply(lambda v: json.loads(v))
merged_df.LIB_INDEX = merged_df.LIB_INDEX.apply(lambda v: json.loads(v))

# put number of data points into meaningful bins
evaluation_bins = [0, 0.5, 1, 2, 3, 4, 6, 10, 20, 50, 100, np.inf]
group_names =     ["0", '1', '2', '3', '4', '5-6', '7-10', '11-20', '21-50', '51-100', '>100']


merged_df["N_DP_SIMPLE"] = pd.cut(merged_df['N_SIGNALS_FILTERED'], bins=evaluation_bins,
                                labels=group_names,
                                  include_lowest=True, right=True)

merged_df
# Out:
#                                                 FILENAME  SCAN_NUMBER  \
# 0                       20220601_pluskal_mce_1D1_A1.mzML          804
# 1                       20220601_pluskal_mce_1D1_A1.mzML          805
# 2                       20220601_pluskal_mce_1D1_A1.mzML          806
# 3                       20220601_pluskal_mce_1D1_A1.mzML          743
# 4                       20220601_pluskal_mce_1D1_A1.mzML          744
# ...                                                  ...          ...
# 55444  20220613_100AGC_60000Res_pluskal_mce_1D1_A23.mzML          595
# 55445  20220613_100AGC_60000Res_pluskal_mce_1D1_A23.mzML          596
# 55446  20220613_100AGC_60000Res_pluskal_mce_1D1_A23.mzML          561
# 55447  20220613_100AGC_60000Res_pluskal_mce_1D1_A23.mzML          562
# 55448  20220613_100AGC_60000Res_pluskal_mce_1D1_A23.mzML          563
#
#        TREE_ID  MS_LEVEL  PRECURSOR_MZ  PRECURSOR_MS2  \
# 0            1         2    1167.31567     1167.31567
# 1            1         2    1167.31567     1167.31567
# 2            1         2    1167.31567     1167.31567
# 3            2         2    1147.27490     1147.27490
# 4            2         2    1147.27490     1147.27490
# ...        ...       ...           ...            ...
# 55444      450         4      95.00867      177.05070
# 55445      450         4      95.00867      177.05070
# 55446      450         3     105.06558      177.05070
# 55447      450         3     105.06558      177.05070
# 55448      450         3     105.06558      177.05070
#
#                         PRECURSOR_LIST  N_SIGNALS  MAX_MSN  N_PREC  ...  \
# 0                         [1167.31567]         18        2       0  ...
# 1                         [1167.31567]         14        2       0  ...
# 2                         [1167.31567]         12        2       0  ...
# 3                          [1147.2749]         17        2       0  ...
# 4                          [1147.2749]         12        2       0  ...
# ...                                ...        ...      ...     ...  ...
# 55444  [177.0507, 106.99969, 95.00867]         33        4       8  ...
# 55445  [177.0507, 106.99969, 95.00867]         28        4       8  ...
# 55446            [177.0507, 105.06558]         43        4       8  ...
# 55447            [177.0507, 105.06558]         38        4       8  ...
# 55448            [177.0507, 105.06558]         34        4       8  ...
#
#        MIN_INTENSITY  N_SIGNALS_FILTERED  LIB_INDEX  PRODUCT_NAME  \
# 0             3305.0                   1         []           NaN
# 1             3574.0                   2         []           NaN
# 2             3620.0                   0         []           NaN
# 3             3261.0                   1         []           NaN
# 4             3523.0                   1         []           NaN
# ...              ...                 ...        ...           ...
# 55444          894.0                   1      [222]    Dencichine
# 55445          958.0                   2      [222]    Dencichine
# 55446          944.0                  15      [222]    Dencichine
# 55447          926.0                  12      [222]    Dencichine
# 55448          993.0                  11      [222]    Dencichine
#
#                              SMILES  EXACT_MASS  ANNOTATED  N_MATCHES  \
# 0                               NaN         NaN      False          0
# 1                               NaN         NaN      False          0
# 2                               NaN         NaN      False          0
# 3                               NaN         NaN      False          0
# 4                               NaN         NaN      False          0
# ...                             ...         ...        ...        ...
# 55444  N[C@@H](CNC(C(O)=O)=O)C(O)=O  176.043321       True          1
# 55445  N[C@@H](CNC(C(O)=O)=O)C(O)=O  176.043321       True          1
# 55446  N[C@@H](CNC(C(O)=O)=O)C(O)=O  176.043321       True          1
# 55447  N[C@@H](CNC(C(O)=O)=O)C(O)=O  176.043321       True          1
# 55448  N[C@@H](CNC(C(O)=O)=O)C(O)=O  176.043321       True          1
#
#                METHOD  N_DP_SIMPLE
# 0               40AGC            1
# 1               40AGC            2
# 2               40AGC            0
# 3               40AGC            1
# 4               40AGC            1
# ...               ...          ...
# 55444  100AGC60000Res            1
# 55445  100AGC60000Res            2
# 55446  100AGC60000Res        11-20
# 55447  100AGC60000Res        11-20
# 55448  100AGC60000Res        11-20
#
# [55449 rows x 34 columns]

# %%
# compare first all spectra
plt.figure(figsize=(20, 9))
ax = sns.histplot(data=merged_df, x="N_DP_SIMPLE", hue="METHOD", fill=False)
# ax.set_ylim(0,3200)
save_fig("n_signals_filtered_categories_all_spectra_pp")

# %%
merged_df["METHOD"].value_counts()
# Out:
# 40AGC             20550
# 100AGC            18950
# 100AGC60000Res    15949
# Name: METHOD, dtype: int64

# %% [markdown]
# ## Filter for unique library matches, for each method, and each precursor mz

# %%
# find all with match, keep best spectrum (highest N of signals) for each precursor of each compound
merged_df = merged_df[merged_df["N_MATCHES"] >= 1]
merged_df["FIRST_LIB_INDEX"] = [lib_ids[0] if len(lib_ids)>0 else "" for lib_ids in merged_df['LIB_INDEX']]
merged_df["PRECURSOR_MZ_LOW_RES"] = [round(mz, 2) for mz in merged_df['PRECURSOR_MZ']]
merged_df = merged_df.sort_values('N_SIGNALS_FILTERED', ascending=False).drop_duplicates(['FIRST_LIB_INDEX','PRECURSOR_MZ_LOW_RES', 'METHOD'], keep="first").sort_index()
merged_df
# Out:
# C:\Users\BrungsC\AppData\Local\Temp\ipykernel_16912\567998582.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   merged_df["FIRST_LIB_INDEX"] = [lib_ids[0] if len(lib_ids)>0 else "" for lib_ids in merged_df['LIB_INDEX']]
# C:\Users\BrungsC\AppData\Local\Temp\ipykernel_16912\567998582.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   merged_df["PRECURSOR_MZ_LOW_RES"] = [round(mz, 2) for mz in merged_df['PRECURSOR_MZ']]
#                                                 FILENAME  SCAN_NUMBER  \
# 38                      20220601_pluskal_mce_1D1_A1.mzML          275
# 41                      20220601_pluskal_mce_1D1_A1.mzML          810
# 51                      20220601_pluskal_mce_1D1_A1.mzML         1143
# 79                      20220601_pluskal_mce_1D1_A1.mzML          414
# 81                      20220601_pluskal_mce_1D1_A1.mzML          419
# ...                                                  ...          ...
# 55434  20220613_100AGC_60000Res_pluskal_mce_1D1_A23.mzML          564
# 55437  20220613_100AGC_60000Res_pluskal_mce_1D1_A23.mzML          558
# 55440  20220613_100AGC_60000Res_pluskal_mce_1D1_A23.mzML          570
# 55445  20220613_100AGC_60000Res_pluskal_mce_1D1_A23.mzML          596
# 55446  20220613_100AGC_60000Res_pluskal_mce_1D1_A23.mzML          561
#
#        TREE_ID  MS_LEVEL  PRECURSOR_MZ  PRECURSOR_MS2  \
# 38           6         2     584.16455      584.16455
# 41           6         2     584.16571      584.16455
# 51           6         3     486.18845      584.16455
# 79           8         2     562.12012      562.12012
# 81           8         3     206.14131      562.12012
# ...        ...       ...           ...            ...
# 55434      450         3     117.00294      177.05070
# 55437      450         3     116.03395      177.05070
# 55440      450         3     106.99969      177.05070
# 55445      450         4      95.00867      177.05070
# 55446      450         3     105.06558      177.05070
#
#                         PRECURSOR_LIST  N_SIGNALS  MAX_MSN  N_PREC  ...  \
# 38                         [584.16455]        126        3       1  ...
# 41                         [584.16455]         60        3       1  ...
# 51              [584.16455, 486.18799]         16        3       1  ...
# 79                         [562.12012]         49        4       7  ...
# 81              [562.12012, 206.14131]         14        4       7  ...
# ...                                ...        ...      ...     ...  ...
# 55434            [177.0507, 117.00294]         68        4       8  ...
# 55437            [177.0507, 116.03395]         72        4       8  ...
# 55440            [177.0507, 106.99969]         94        4       8  ...
# 55445  [177.0507, 106.99969, 95.00867]         28        4       8  ...
# 55446            [177.0507, 105.06558]         43        4       8  ...
#
#        LIB_INDEX      PRODUCT_NAME  \
# 38           [3]  Fostemsavir Tris
# 41           [3]  Fostemsavir Tris
# 51           [3]  Fostemsavir Tris
# 79           [5]   ALK inhibitor 1
# 81           [5]   ALK inhibitor 1
# ...          ...               ...
# 55434      [222]        Dencichine
# 55437      [222]        Dencichine
# 55440      [222]        Dencichine
# 55445      [222]        Dencichine
# 55446      [222]        Dencichine
#
#                                                   SMILES  EXACT_MASS  \
# 38     O=C(N1CCN(C(C2=CC=CC=C2)=O)CC1)C(C3=CN(COP(O)(...  583.158047
# 41     O=C(N1CCN(C(C2=CC=CC=C2)=O)CC1)C(C3=CN(COP(O)(...  583.158047
# 51     O=C(N1CCN(C(C2=CC=CC=C2)=O)CC1)C(C3=CN(COP(O)(...  583.158047
# 79     O=S(C1=C(NC2=C(Br)C=NC(NC3=C(OC)C=C(N4CCN(C)CC...  561.115771
# 81     O=S(C1=C(NC2=C(Br)C=NC(NC3=C(OC)C=C(N4CCN(C)CC...  561.115771
# ...                                                  ...         ...
# 55434                       N[C@@H](CNC(C(O)=O)=O)C(O)=O  176.043321
# 55437                       N[C@@H](CNC(C(O)=O)=O)C(O)=O  176.043321
# 55440                       N[C@@H](CNC(C(O)=O)=O)C(O)=O  176.043321
# 55445                       N[C@@H](CNC(C(O)=O)=O)C(O)=O  176.043321
# 55446                       N[C@@H](CNC(C(O)=O)=O)C(O)=O  176.043321
#
#        ANNOTATED  N_MATCHES          METHOD  N_DP_SIMPLE  FIRST_LIB_INDEX  \
# 38          True          1           40AGC       51-100                3
# 41          True          1           40AGC        21-50                3
# 51          True          1           40AGC            4                3
# 79          True          1           40AGC        11-20                5
# 81          True          1           40AGC         7-10                5
# ...          ...        ...             ...          ...              ...
# 55434       True          1  100AGC60000Res        21-50              222
# 55437       True          1  100AGC60000Res        21-50              222
# 55440       True          1  100AGC60000Res        21-50              222
# 55445       True          1  100AGC60000Res            2              222
# 55446       True          1  100AGC60000Res        11-20              222
#
#        PRECURSOR_MZ_LOW_RES
# 38                   584.16
# 41                   584.17
# 51                   486.19
# 79                   562.12
# 81                   206.14
# ...                     ...
# 55434                117.00
# 55437                116.03
# 55440                107.00
# 55445                 95.01
# 55446                105.07
#
# [5987 rows x 36 columns]

# %%
plt.figure(figsize=(20, 6))
ax = sns.histplot(data=merged_df, x="N_SIGNALS_FILTERED", hue="METHOD", binwidth=2, fill=False, element="step")
ax.set_xlim(0,150)
# ax.set_ylim(0,100)
save_fig("histo_signals_gr_3xmin_intensity")

# %%
plt.figure(figsize=(20, 9))
ax = sns.histplot(data=merged_df, x="N_DP_SIMPLE", hue="METHOD", fill=False)
save_fig("n_signals_filtered_categories_pp")

# %%
merged_df["METHOD"].value_counts()
# Out:
# 40AGC             2126
# 100AGC            2010
# 100AGC60000Res    1851
# Name: METHOD, dtype: int64

# %%
best_df = merged_df.sort_values('N_SIGNALS_FILTERED', ascending=False).drop_duplicates(['FIRST_LIB_INDEX', "PRECURSOR_MZ_LOW_RES"], keep="first").sort_index()

# %%
best_df
# Out:
#                                                 FILENAME  SCAN_NUMBER  \
# 38                      20220601_pluskal_mce_1D1_A1.mzML          275
# 51                      20220601_pluskal_mce_1D1_A1.mzML         1143
# 185                     20220601_pluskal_mce_1D1_A1.mzML          243
# 189                     20220601_pluskal_mce_1D1_A1.mzML          250
# 217                     20220601_pluskal_mce_1D1_A1.mzML          263
# ...                                                  ...          ...
# 55434  20220613_100AGC_60000Res_pluskal_mce_1D1_A23.mzML          564
# 55437  20220613_100AGC_60000Res_pluskal_mce_1D1_A23.mzML          558
# 55440  20220613_100AGC_60000Res_pluskal_mce_1D1_A23.mzML          570
# 55445  20220613_100AGC_60000Res_pluskal_mce_1D1_A23.mzML          596
# 55446  20220613_100AGC_60000Res_pluskal_mce_1D1_A23.mzML          561
#
#        TREE_ID  MS_LEVEL  PRECURSOR_MZ  PRECURSOR_MS2  \
# 38           6         2     584.16455      584.16455
# 51           6         3     486.18845      584.16455
# 185         15         2     426.21338      426.21338
# 189         15         3     328.14023      426.21338
# 217         15         4     226.07220      426.21338
# ...        ...       ...           ...            ...
# 55434      450         3     117.00294      177.05070
# 55437      450         3     116.03395      177.05070
# 55440      450         3     106.99969      177.05070
# 55445      450         4      95.00867      177.05070
# 55446      450         3     105.06558      177.05070
#
#                          PRECURSOR_LIST  N_SIGNALS  MAX_MSN  N_PREC  ...  \
# 38                          [584.16455]        126        3       1  ...
# 51               [584.16455, 486.18799]         16        3       1  ...
# 185                         [426.21338]        112        5      11  ...
# 189              [426.21338, 328.14023]          8        5      11  ...
# 217    [426.21338, 269.09134, 226.0722]         17        5      11  ...
# ...                                 ...        ...      ...     ...  ...
# 55434             [177.0507, 117.00294]         68        4       8  ...
# 55437             [177.0507, 116.03395]         72        4       8  ...
# 55440             [177.0507, 106.99969]         94        4       8  ...
# 55445   [177.0507, 106.99969, 95.00867]         28        4       8  ...
# 55446             [177.0507, 105.06558]         43        4       8  ...
#
#        LIB_INDEX      PRODUCT_NAME  \
# 38           [3]  Fostemsavir Tris
# 51           [3]  Fostemsavir Tris
# 185          [8]       PF-04691502
# 189          [8]       PF-04691502
# 217          [8]       PF-04691502
# ...          ...               ...
# 55434      [222]        Dencichine
# 55437      [222]        Dencichine
# 55440      [222]        Dencichine
# 55445      [222]        Dencichine
# 55446      [222]        Dencichine
#
#                                                   SMILES  EXACT_MASS  \
# 38     O=C(N1CCN(C(C2=CC=CC=C2)=O)CC1)C(C3=CN(COP(O)(...  583.158047
# 51     O=C(N1CCN(C(C2=CC=CC=C2)=O)CC1)C(C3=CN(COP(O)(...  583.158047
# 185    OCCO[C@@H]1CC[C@@H](N2C(N=C(N)N=C3C)=C3C=C(C4=...  425.206304
# 189    OCCO[C@@H]1CC[C@@H](N2C(N=C(N)N=C3C)=C3C=C(C4=...  425.206304
# 217    OCCO[C@@H]1CC[C@@H](N2C(N=C(N)N=C3C)=C3C=C(C4=...  425.206304
# ...                                                  ...         ...
# 55434                       N[C@@H](CNC(C(O)=O)=O)C(O)=O  176.043321
# 55437                       N[C@@H](CNC(C(O)=O)=O)C(O)=O  176.043321
# 55440                       N[C@@H](CNC(C(O)=O)=O)C(O)=O  176.043321
# 55445                       N[C@@H](CNC(C(O)=O)=O)C(O)=O  176.043321
# 55446                       N[C@@H](CNC(C(O)=O)=O)C(O)=O  176.043321
#
#        ANNOTATED  N_MATCHES          METHOD  N_DP_SIMPLE  FIRST_LIB_INDEX  \
# 38          True          1           40AGC       51-100                3
# 51          True          1           40AGC            4                3
# 185         True          1           40AGC       51-100                8
# 189         True          1           40AGC            2                8
# 217         True          1           40AGC            4                8
# ...          ...        ...             ...          ...              ...
# 55434       True          1  100AGC60000Res        21-50              222
# 55437       True          1  100AGC60000Res        21-50              222
# 55440       True          1  100AGC60000Res        21-50              222
# 55445       True          1  100AGC60000Res            2              222
# 55446       True          1  100AGC60000Res        11-20              222
#
#        PRECURSOR_MZ_LOW_RES
# 38                   584.16
# 51                   486.19
# 185                  426.21
# 189                  328.14
# 217                  226.07
# ...                     ...
# 55434                117.00
# 55437                116.03
# 55440                107.00
# 55445                 95.01
# 55446                105.07
#
# [2624 rows x 36 columns]

# %%
best_df["METHOD"].value_counts()
# Out:
# 100AGC60000Res    1472
# 100AGC             660
# 40AGC              492
# Name: METHOD, dtype: int64

# %%
plt.figure(figsize=(20, 9))
ax = sns.histplot(data=best_df, x="N_DP_SIMPLE", hue="METHOD", fill=False)
save_fig("n_signals_best_filtered_categories_pp")
